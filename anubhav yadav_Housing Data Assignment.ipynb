# %%
#importing the library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### import the data Set

# %%
df = pd.read_csv('D:\python\Data Sheet/House data.csv')
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# 1             2570      7242     2.0           0     0  ...      7
# 2              770     10000     1.0           0     0  ...      6
# 3             1960      5000     1.0           0     0  ...      7
# 4             1680      8080     1.0           0     0  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21613 rows x 21 columns]

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Data Cleaning - remove irrelevant columns.

# %%
x= df.drop(['id','date','grade','zipcode','long','lat','long'],axis=1)
x.head()
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900.0         3       1.00         1180      5650     1.0           0
# 1  538000.0         3       2.25         2570      7242     2.0           0
# 2  180000.0         2       1.00          770     10000     1.0           0
# 3  604000.0         4       3.00         1960      5000     1.0           0
# 4  510000.0         3       2.00         1680      8080     1.0           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3        1180              0      1955             0
# 1     0          3        2170            400      1951          1991
# 2     0          3         770              0      1933             0
# 3     0          5        1050            910      1965             0
# 4     0          3        1680              0      1987             0
#
#    sqft_living15  sqft_lot15
# 0           1340        5650
# 1           1690        7639
# 2           2720        8062
# 3           1360        5000
# 4           1800        7503

# %%
y=df[['price']]

# %% [markdown]
# ### Exploratory data analysis - Visualization: Univariate, Bivariate, Multivariate.

# %%
sns.pairplot(x)

# %% [markdown]
# ### Split the dataset into training and testing

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=.30,random_state=1)

# %%
print("Set size of x",x.shape)
print("train set size of x",x_train.shape)
print("train set size of y",y_train.shape)
# Out:
# Set size of x (21613, 16)
# train set size of x (15129, 16)
# train set size of y (15129, 1)

# %%
print("train set size of x",x_test.shape)
print("train set size of y",y_test.shape)
# Out:
# train set size of x (6484, 16)
# train set size of y (6484, 1)

# %% [markdown]
# ### Building a model

# %%
from sklearn.linear_model import LinearRegression
from sklearn import metrics

# %%
lr = LinearRegression() # creating a linear Regression object "lr"

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print("The intercept term of the liner model:",lr.intercept_)
print("The coefficient of the linear model ",lr.coef_)
# Out:
# The intercept term of the liner model: [-1.62981451e-09]
# The coefficient of the linear model  [[ 1.00000000e+00 -1.35019965e-12 -1.45288071e-11  1.47460305e-14
#    5.33533562e-17  1.42255536e-11  1.08130986e-10 -1.37638838e-11
#    2.56789056e-12  4.75831863e-15  9.98688327e-15 -1.60275198e-13
#   -1.26925066e-15  3.01895668e-11 -4.33704667e-15  4.50402276e-17]]

# %%
train_pred = lr.predict(x_train)

# %%
metrics.mean_squared_error(y_train,train_pred)
# Out:
# 9.568031879979359e-20

# %%
test_pred = lr.predict(x_test)

# %%
print("Training Data(Mean Squared Error)", metrics.mean_squared_error(y_train,train_pred))
print("Training Data(Mean Absolute Error)",metrics.mean_absolute_error(y_train,train_pred))
print("Training Data(Root Mean Square Error)",np.sqrt(metrics.mean_squared_error(y_train,train_pred)))
# Out:
# Training Data(Mean Squared Error) 9.568031879979359e-20
# Training Data(Mean Absolute Error) 1.9881365416570636e-10
# Training Data(Root Mean Square Error) 3.093223541870092e-10

# %%
print("Test Data(Mean Squared Error)", metrics.mean_squared_error(y_test,test_pred))
print("Test Data(Mean Absolute Error)",metrics.mean_absolute_error(y_test,test_pred))
print("Test Data(Root Mean Square Error)",np.sqrt(metrics.mean_squared_error(y_test,test_pred)))
# Out:
# Test Data(Mean Squared Error) 1.1895447104125193e-19
# Test Data(Mean Absolute Error) 2.0478386934651298e-10
# Test Data(Root Mean Square Error) 3.44897768971114e-10

# %% [markdown]
# ### Evaluation metrics - RMSE, MSE, MAE, R-square

# %%
prediction= lr.predict(x_test)

# %%
print("Mean Squared Error",metrics.mean_squared_error(prediction,y_test))
print("Root Mean squared Error",np.sqrt(metrics.mean_squared_error(prediction,y_test)))
# Out:
# Mean Squared Error 1.1895447104125193e-19
# Root Mean squared Error 3.44897768971114e-10

# %%
print("R-Square Value of predictions", round(metrics.r2_score(y_test,prediction),2))
# Out:
# R-Square Value of predictions 1.0
